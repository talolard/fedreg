# %%
import bs4
import lxml
import pandas as pd
from flashtext import KeywordProcessor

# %%
def rule_to_dict(rule,_type):
    '''
    Gets a rule, and its type (rule/prorule), return a dictionary with the metadata we need and list of 
    paragraphras
    '''
    preamble = rule.PREAMB
    paragraphs = list(filter(lambda x: len(x)>5,rule.text.split('\n')))
    return {
        'type':_type,
        'agency':preamble.AGENCY.text,
        'title':preamble.SUBJECT.text,
        'doc_id':rule.FRDOC.text , #Use this as an aggregation code
        'paragraphs':paragraphs
    }

# %%
def rule_results_to_examples(rr):
    '''
    Given a rule, return a list of examples (in lighttag format)
    '''
    paragraphs = rr.pop('paragraphs') #Pop it so we don't append the paragraphs on each example
    results =[] 
    for num,p in enumerate(paragraphs):
        res = {'content':p,'order_code':num} #use doc_id as aggregation code, order_code is the order the ps appeared
        res.update(rr)## add the metadata from the document 
        results.append(res) #append it to the list of results
    return results

# %%
def fr_file_to_example_list(file_path):
    soup =bs4.BeautifulSoup(open(file_path),"lxml-xml")
    rules = soup.FEDREG.RULES.findAll('RULE')
    proposedRules = soup.FEDREG.PRORULES.findAll("PRORULE")
    ruleResults = map(lambda x: rule_to_dict(x,_type='rule'),rules)
    proRuleResults  = map(lambda x: rule_to_dict(x,_type='prorule'),proposedRules)
    results = list(ruleResults)+list(proRuleResults)
    examples = sum(map(rule_results_to_examples,results),[])
    return examples

# %%
import os
data =[]
base ='./data/bulk-fr/'
error_paths = []
for yr in os.listdir(base):
    yrdir = os.path.join(base,yr)
    for mnth in os.listdir(yrdir):
        if len(mnth)==2:
            pb = os.path.join(yrdir,mnth)
            print(mnth)

            for f in os.listdir(pb):
                if f.endswith('xml'):
                    path = os.path.join(pb,f)
                    try:
                        data += fr_file_to_example_list(path)
                    except:
                        error_paths.append(path)
# Out:
# 11
# 10
# 02
# 09
# 06
# 07
# 08
# 04
# 01
# 05
# 12
# 03
# 11
# 10
# 02
# 09
# 06
# 07
# 08
# 04
# 01
# 05
# 12
# 03
# 11
# 10
# 02
# 09
# 06
# 07
# 08
# 04
# 01
# 05
# 12
# 03
# 10
# 02
# 09
# 06
# 07
# 08
# 04
# 01
# 05
# 03

# %%
import re
captializedTermReg = re.compile('([A-Z][a-z]+?\s){2,}([A-Z][a-z]+)')
m = captializedTermReg.match("Tal Pery Ate Big Food In")
KW = KeywordProcessor(case_sensitive=False)
KWG =KeywordProcessor(case_sensitive=False)
phrease_terms = ['treaty','convention','agreement',]
other_terms =['bilateral agreement','international agreement','executive agreement',
        'multilateral agreement','law of nations','law of armed conflict','international humanitarian law',
         'international custom','state practice','opinio juris','sense of legal obligation'
        ]

KW.add_keywords_from_list(phrease_terms,)
KWG.add_keywords_from_list(other_terms)
def find_all(text):
    res= []
    for m in captializedTermReg.finditer(text):
        t = KW.extract_keywords(m.group(0).lower())
        if t:
            res.append({'phrase':m.group(0),'key':t[0],'start':m.start(),'end':m.end()})
    for term,start,end in KWG.extract_keywords(text,span_info=True):
        res.append({'phrase':term,'key':term,'start':start,'end':end})
    return res

# %%
KW.extract_keywords("My treaty is here",span_info=True)
# Out:
# [('treaty', 3, 9)]

# %%
def attach_or_none(item):
    ress = find_all(item['content'])
    if ress:
        for res in ress:
            res.update(item)
        return ress
    else:
        return None
matches = sum(filter(lambda x:x,map(attach_or_none,data)),[])
len(data),len(matches)
# Out:
# (2369805, 3198)

# %%
pd.DataFrame(matches)
# Out:
#                                        agency  \
# 0                      DEPARTMENT OF COMMERCE
# 1                      DEPARTMENT OF COMMERCE
# 2                      DEPARTMENT OF COMMERCE
# 3                      DEPARTMENT OF COMMERCE
# 4                      DEPARTMENT OF COMMERCE
# 5                      DEPARTMENT OF COMMERCE
# 6                  DEPARTMENT OF THE INTERIOR
# 7                  DEPARTMENT OF THE INTERIOR
# 8                DEPARTMENT OF TRANSPORTATION
# 9                DEPARTMENT OF TRANSPORTATION
# 10               DEPARTMENT OF TRANSPORTATION
# 11               DEPARTMENT OF TRANSPORTATION
# 12                 DEPARTMENT OF THE TREASURY
# 13                 DEPARTMENT OF THE TREASURY
# 14               DEPARTMENT OF TRANSPORTATION
# 15               DEPARTMENT OF TRANSPORTATION
# 16                  DEPARTMENT OF AGRICULTURE
# 17                       DEPARTMENT OF ENERGY
# 18                  DEPARTMENT OF AGRICULTURE
# 19                  DEPARTMENT OF AGRICULTURE
# 20               DEPARTMENT OF TRANSPORTATION
# 21               DEPARTMENT OF TRANSPORTATION
# 22                     DEPARTMENT OF COMMERCE
# 23                     DEPARTMENT OF COMMERCE
# 24                     DEPARTMENT OF COMMERCE
# 25                     DEPARTMENT OF COMMERCE
# 26            DEPARTMENT OF HOMELAND SECURITY
# 27                 DEPARTMENT OF THE INTERIOR
# 28                  DEPARTMENT OF AGRICULTURE
# 29               DEPARTMENT OF TRANSPORTATION
# ...                                       ...
# 3168             DEPARTMENT OF TRANSPORTATION
# 3169             DEPARTMENT OF TRANSPORTATION
# 3170             DEPARTMENT OF TRANSPORTATION
# 3171             DEPARTMENT OF TRANSPORTATION
# 3172             DEPARTMENT OF TRANSPORTATION
# 3173             DEPARTMENT OF TRANSPORTATION
# 3174             DEPARTMENT OF TRANSPORTATION
# 3175             DEPARTMENT OF TRANSPORTATION
# 3176                DEPARTMENT OF AGRICULTURE
# 3177             DEPARTMENT OF TRANSPORTATION
# 3178                   DEPARTMENT OF COMMERCE
# 3179                   DEPARTMENT OF COMMERCE
# 3180                   DEPARTMENT OF COMMERCE
# 3181             DEPARTMENT OF TRANSPORTATION
# 3182             POSTAL REGULATORY COMMISSION
# 3183             POSTAL REGULATORY COMMISSION
# 3184             DEPARTMENT OF TRANSPORTATION
# 3185             DEPARTMENT OF TRANSPORTATION
# 3186               DEPARTMENT OF THE INTERIOR
# 3187               DEPARTMENT OF THE INTERIOR
# 3188             DEPARTMENT OF TRANSPORTATION
# 3189                   DEPARTMENT OF COMMERCE
# 3190             DEPARTMENT OF TRANSPORTATION
# 3191             DEPARTMENT OF TRANSPORTATION
# 3192             DEPARTMENT OF TRANSPORTATION
# 13    Centralized Partnership Audit Regime: Internat...  prorule
# 14    Airworthiness Directives; AgustaWestland S.p.A...  prorule
# 15    Airworthiness Directives; Agusta S.p.A. Helico...  prorule
# 16    Oranges, Grapefruit, Tangerines, and Pummelos ...     rule
# 17    Offer Caps in Markets Operated by Regional Tra...     rule
# 18    Walnuts Grown in California; Decreased Assessm...     rule
# 19    Pecans Grown in the States of Alabama, Arkansa...     rule
# 20    Airworthiness Directives; Airbus Helicopters D...     rule
# 21    Airworthiness Directives; Bombardier, Inc., Ai...  prorule
# 22    Clarifications to the Export Administration Re...     rule
# 23    Clarifications to the Export Administration Re...     rule
# 24    Clarifications to the Export Administration Re...     rule
# 25    Clarifications to the Export Administration Re...     rule
# 26    Procedures To Adjust Customs COBRA User Fees T...     rule
# 27    Final Report: Review of the Department of the ...     rule
# 28    Rules of Practice and Procedure Governing Form...     rule
# 29    Airworthiness Directives; Safran Helicopter En...  prorule
# ...                                                 ...      ...
# 3168  Airworthiness Directives; Airbus Helicopters D...     rule
# 3169  Airworthiness Directives; Leonardo S.p.A. Heli...     rule
# 3170  Seaway Regulations and Rules: Periodic Update,...     rule
# 3171  Seaway Regulations and Rules: Periodic Update,...     rule
# 3172  Seaway Regulations and Rules: Periodic Update,...     rule
# 3173                                    Tariff of Tolls     rule
# 3174                                    Tariff of Tolls     rule
# 3175                                    Tariff of Tolls     rule
# 3176  Federal Milk Marketing Orders—Amending the Cla...     rule
# 3177  Airworthiness Directives; Empresa Brasileira d...     rule
# 3178  International Affairs; Antarctic Marine Living...     rule
# 3179  International Affairs; Antarctic Marine Living...     rule
# 3180  International Affairs; Antarctic Marine Living...     rule
# 3181  Airworthiness Directives; Dassault Aviation Ai...     rule
# 3182                             Update to Product List     rule
# 3183                             Update to Product List     rule
# 3184  Airworthiness Directives; Rolls-Royce Deutschl...  prorule
# 3185     Airworthiness Directives; Airbus SAS Airplanes  prorule
# 3186           Financial Assistance Interior Regulation  prorule
# 3187           Financial Assistance Interior Regulation  prorule
# 3188  Airworthiness Directives; Bombardier, Inc., Ai...  prorule
# 3189  Atlantic Highly Migratory Species; Atlantic Bl...     rule
# 3190     Airworthiness Directives; Airbus SAS Airplanes     rule
# 3191  Hazardous Materials: Enhanced Safety Provision...     rule
# 3192  Commercial Driver's License Upgrade from Class...     rule
# 3193  Medicare Program; Release of Data Underlying R...  prorule
# 3194  Chapter 4 Regulations Relating to Verification...     rule
# 3195  Proposed Amendments to Regulations Governing V...  prorule
# 3196  Airworthiness Directives; Bombardier, Inc., Ai...  prorule
# 3197  Special Local Regulations; Sector Ohio Valley ...  prorule
#
# [3198 rows x 10 columns]

# %%
S = pd.DataFrame(matches)
len(S.drop_duplicates('content'))
# Out:
# 1818

# %%
S.drop_duplicates('content').to_json('~/dev/lighttag/sample_data/fedreg.json',orient='records')

# %%
S.key.unique()
# Out:
# array(['treaty', 'bilateral agreement', 'agreement', 'convention',
#        'international agreement', 'multilateral agreement',
#        'executive agreement', 'state practice',
#        'international humanitarian law'], dtype=object)
